# %%
Pandas two datatype = series and dataframes

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
for n in range(1,10):
    time.sleep(1)
    x=np.random.randint(10,100,10)
    plt.hist(x)
    plt.clf()
    plt.plot()
